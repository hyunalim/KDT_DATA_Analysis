# %% [markdown]
# ## 데이터 준비
# - https://www.kaggle.com/datasets/harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows/

# %%
import pandas as pd

# %%
cols = ['Released_Year', 'Genre', 'Series_Title', 'Director', 'Meta_score', 'IMDB_Rating', 'No_of_Votes', 'Certificate', 'Gross']

# %%
# 가져올 열 지정하기
movie_df = pd.read_csv('imdb_top_1000.csv')
movie_df = movie_df[cols]
movie_df
# Out:
#     Released_Year                     Genre              Series_Title  \
# 0            1994                     Drama  The Shawshank Redemption
# 1            1972              Crime, Drama             The Godfather
# 2            2008      Action, Crime, Drama           The Dark Knight
# 3            1974              Crime, Drama    The Godfather: Part II
# 4            1957              Crime, Drama              12 Angry Men
# ..            ...                       ...                       ...
# 995          1961    Comedy, Drama, Romance    Breakfast at Tiffany's
# 996          1956            Drama, Western                     Giant
# 997          1953       Drama, Romance, War     From Here to Eternity
# 998          1944                Drama, War                  Lifeboat
# 999          1935  Crime, Mystery, Thriller              The 39 Steps
#
#                  Director  Meta_score  IMDB_Rating  No_of_Votes Certificate  \
# 0          Frank Darabont        80.0          9.3      2343110           A
# 1    Francis Ford Coppola       100.0          9.2      1620367           A
# 2       Christopher Nolan        84.0          9.0      2303232          UA
# 3    Francis Ford Coppola        90.0          9.0      1129952           A
# 4            Sidney Lumet        96.0          9.0       689845           U
# ..                    ...         ...          ...          ...         ...
# 995         Blake Edwards        76.0          7.6       166544           A
# 996        George Stevens        84.0          7.6        34075           G
# 997        Fred Zinnemann        85.0          7.6        43374      Passed
# 998      Alfred Hitchcock        78.0          7.6        26471         NaN
# 999      Alfred Hitchcock        93.0          7.6        51853         NaN
#
#            Gross
# 0     28,341,469
# 1    134,966,411
# 2    534,858,444
# 3     57,300,000
# 4      4,360,000
# ..           ...
# 995          NaN
# 996          NaN
# 997   30,500,000
# 998          NaN
# 999          NaN
#
# [1000 rows x 9 columns]

# %% [markdown]
# ## .nlargest()

# %% [markdown]
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.nlargest.html#pandas.DataFrame.nlargest
#
# >**n : int**
# Number of rows to return.
#
# >**columns : label or list of labels**
# Column label(s) to order by.
#
# >**keep : {‘first’, ‘last’, ‘all’}, default ‘first’**
# Where there are duplicate values:
#
# **중복된 값이 있을 경우 우선순위**
# - first : prioritize the first occurrence(s)
# - last : prioritize the last occurrence(s)
# - all : do not drop any duplicates, even it means selecting more than n items.

# %%
movie_df.nlargest(n=5,columns=['IMDB_Rating'])
# Out:
#   Released_Year                 Genre              Series_Title  \
# 0          1994                 Drama  The Shawshank Redemption
# 1          1972          Crime, Drama             The Godfather
# 2          2008  Action, Crime, Drama           The Dark Knight
# 3          1974          Crime, Drama    The Godfather: Part II
# 4          1957          Crime, Drama              12 Angry Men
#
#                Director  Meta_score  IMDB_Rating  No_of_Votes Certificate  \
# 0        Frank Darabont        80.0          9.3      2343110           A
# 1  Francis Ford Coppola       100.0          9.2      1620367           A
# 2     Christopher Nolan        84.0          9.0      2303232          UA
# 3  Francis Ford Coppola        90.0          9.0      1129952           A
# 4          Sidney Lumet        96.0          9.0       689845           U
#
#          Gross
# 0   28,341,469
# 1  134,966,411
# 2  534,858,444
# 3   57,300,000
# 4    4,360,000

# %% [markdown]
# nlargest()는 아래 코드를 쉽게 만든거라고도 볼 수 있다.
# nlargest()를 쓰지 않고 코드를 작성해보면 할 수는 있다.

# %%
# 이미 공식 문서에 소개된 내용
movie_df.sort_values(by='IMDB_Rating', ascending=False).head()
# Out:
#   Released_Year                 Genre              Series_Title  \
# 0          1994                 Drama  The Shawshank Redemption
# 1          1972          Crime, Drama             The Godfather
# 2          2008  Action, Crime, Drama           The Dark Knight
# 3          1974          Crime, Drama    The Godfather: Part II
# 4          1957          Crime, Drama              12 Angry Men
#
#                Director  Meta_score  IMDB_Rating  No_of_Votes Certificate  \
# 0        Frank Darabont        80.0          9.3      2343110           A
# 1  Francis Ford Coppola       100.0          9.2      1620367           A
# 2     Christopher Nolan        84.0          9.0      2303232          UA
# 3  Francis Ford Coppola        90.0          9.0      1129952           A
# 4          Sidney Lumet        96.0          9.0       689845           U
#
#          Gross
# 0   28,341,469
# 1  134,966,411
# 2  534,858,444
# 3   57,300,000
# 4    4,360,000

# %% [markdown]
# ## .nsmallest()

# %%
# 1차 정렬 IMDB_Rating
movie_df.nsmallest(n=5, columns='IMDB_Rating')
# Out:
#     Released_Year                      Genre  \
# 877          2019  Biography, Drama, History
# 878          2018   Drama, Mystery, Thriller
# 879          2019              Comedy, Drama
# 880          2017                      Drama
# 881          2017                      Drama
#
#                          Series_Title            Director  Meta_score  \
# 877                       Dark Waters         Todd Haynes        73.0
# 878                         Searching     Aneesh Chaganty        71.0
# 879  Once Upon a Time... in Hollywood   Quentin Tarantino        83.0
# 880                          Nelyubov  Andrey Zvyagintsev        86.0
# 881               The Florida Project          Sean Baker        92.0
#
#      IMDB_Rating  No_of_Votes Certificate        Gross
# 877          7.6        60408       PG-13          NaN
# 878          7.6       140840         U/A   26,020,957
# 879          7.6       551309           A  142,502,728
# 880          7.6        29765           R      566,356
# 881          7.6        95181           A    5,904,366

# %%
# 1차 정렬 IMDB_Rating, 2차 정렬 Meta_score
movie_df.nsmallest(n=5, columns=['IMDB_Rating', 'Meta_score'])
# Out:
#     Released_Year                      Genre                    Series_Title  \
# 942          2004    Drama, Sci-Fi, Thriller            The Butterfly Effect
# 917          2008                      Drama                    Seven Pounds
# 957          1998   Adventure, Comedy, Drama  Fear and Loathing in Las Vegas
# 935          2003     Comedy, Drama, Romance                  Jeux d'enfants
# 932          2004  Horror, Mystery, Thriller                             Saw
#
#              Director  Meta_score  IMDB_Rating  No_of_Votes Certificate  \
# 942        Eric Bress        30.0          7.6       451479           U
# 917  Gabriele Muccino        36.0          7.6       286770          UA
# 957     Terry Gilliam        41.0          7.6       259753           R
# 935      Yann Samuell        45.0          7.6        67360           R
# 932         James Wan        46.0          7.6       379020          UA
#
#           Gross
# 942  57,938,693
# 917  69,951,824
# 957  10,680,275
# 935     548,707
# 932  56,000,369

# %% [markdown]
# ## keep=

# %% [markdown]
# **중복된 값이 있는 경우**
# - first : 첫 번째 등장하는 값들을 우선. (default)
# - last : 마지막으로 등장하는 값들을 우선.
# - all : 중복된 값을 제거하지 않고 모든 값들을 선택. 이 경우 n보다 더 많은 항목들이 선택될 수 있다.

# %%
# IMDB_Rating 최고 7개, 동점의 경우 먼저 등장하는 것부터 우선배치
movie_df.nlargest(n=7, columns='IMDB_Rating')
# Out:
#   Released_Year                     Genre  \
# 0          1994                     Drama
# 1          1972              Crime, Drama
# 2          2008      Action, Crime, Drama
# 3          1974              Crime, Drama
# 4          1957              Crime, Drama
# 5          2003  Action, Adventure, Drama
# 6          1994              Crime, Drama
#
#                                     Series_Title              Director  \
# 0                       The Shawshank Redemption        Frank Darabont
# 1                                  The Godfather  Francis Ford Coppola
# 2                                The Dark Knight     Christopher Nolan
# 3                         The Godfather: Part II  Francis Ford Coppola
# 4                                   12 Angry Men          Sidney Lumet
# 5  The Lord of the Rings: The Return of the King         Peter Jackson
# 6                                   Pulp Fiction     Quentin Tarantino
#
#    Meta_score  IMDB_Rating  No_of_Votes Certificate        Gross
# 0        80.0          9.3      2343110           A   28,341,469
# 1       100.0          9.2      1620367           A  134,966,411
# 2        84.0          9.0      2303232          UA  534,858,444
# 3        90.0          9.0      1129952           A   57,300,000
# 4        96.0          9.0       689845           U    4,360,000
# 5        94.0          8.9      1642758           U  377,845,905
# 6        94.0          8.9      1826188           A  107,928,762

# %%
# IMDB_Rating 최고 7개, 동점의 경우 끝에있는 것부터 우선배치
movie_df.nlargest(n=7, columns='IMDB_Rating', keep='last')
# Out:
#   Released_Year                      Genre              Series_Title  \
# 0          1994                      Drama  The Shawshank Redemption
# 1          1972               Crime, Drama             The Godfather
# 4          1957               Crime, Drama              12 Angry Men
# 3          1974               Crime, Drama    The Godfather: Part II
# 2          2008       Action, Crime, Drama           The Dark Knight
# 7          1993  Biography, Drama, History          Schindler's List
# 6          1994               Crime, Drama              Pulp Fiction
#
#                Director  Meta_score  IMDB_Rating  No_of_Votes Certificate  \
# 0        Frank Darabont        80.0          9.3      2343110           A
# 1  Francis Ford Coppola       100.0          9.2      1620367           A
# 4          Sidney Lumet        96.0          9.0       689845           U
# 3  Francis Ford Coppola        90.0          9.0      1129952           A
# 2     Christopher Nolan        84.0          9.0      2303232          UA
# 7      Steven Spielberg        94.0          8.9      1213505           A
# 6     Quentin Tarantino        94.0          8.9      1826188           A
#
#          Gross
# 0   28,341,469
# 1  134,966,411
# 4    4,360,000
# 3   57,300,000
# 2  534,858,444
# 7   96,898,818
# 6  107,928,762

# %%
# IMDB_Rating 최고 7개, 동점의 경우 8개가 넘더라도 추가
movie_df.nlargest(n=7, columns='IMDB_Rating', keep='all')
# Out:
#   Released_Year                      Genre  \
# 0          1994                      Drama
# 1          1972               Crime, Drama
# 2          2008       Action, Crime, Drama
# 3          1974               Crime, Drama
# 4          1957               Crime, Drama
# 5          2003   Action, Adventure, Drama
# 6          1994               Crime, Drama
# 7          1993  Biography, Drama, History
#
#                                     Series_Title              Director  \
# 0                       The Shawshank Redemption        Frank Darabont
# 1                                  The Godfather  Francis Ford Coppola
# 2                                The Dark Knight     Christopher Nolan
# 3                         The Godfather: Part II  Francis Ford Coppola
# 4                                   12 Angry Men          Sidney Lumet
# 5  The Lord of the Rings: The Return of the King         Peter Jackson
# 6                                   Pulp Fiction     Quentin Tarantino
# 7                               Schindler's List      Steven Spielberg
#
#    Meta_score  IMDB_Rating  No_of_Votes Certificate        Gross
# 0        80.0          9.3      2343110           A   28,341,469
# 1       100.0          9.2      1620367           A  134,966,411
# 2        84.0          9.0      2303232          UA  534,858,444
# 3        90.0          9.0      1129952           A   57,300,000
# 4        96.0          9.0       689845           U    4,360,000
# 5        94.0          8.9      1642758           U  377,845,905
# 6        94.0          8.9      1826188           A  107,928,762
# 7        94.0          8.9      1213505           A   96,898,818

# %% [markdown]
# `keep='all'`을 하니 7개를 조회했으나 8개가 나왔다

# %% [markdown]
# ## .sort_values()
# - Series.sort_values : https://pandas.pydata.org/docs/reference/api/pandas.Series.sort_values.html
# - DataFrame.sort_values : https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html
# - Series.sort_values보다 DataFrame.sort_values인자가 'by' 하나 더 있다.
# - Series는 단일 열이 였지만, DataFrame은 다중 열이기에 어떤 열을 정렬할 지, 정렬하려는 열 정보가 필요

# %% [markdown]
# **by : str or list of str**
# Name or list of names to sort by.
# - if axis is 0 or ‘index’ then by may contain index levels and/or column labels.
# - if axis is 1 or ‘columns’ then by may contain column levels and/or index labels.

# %%
movie_df.sort_values(by=['IMDB_Rating','Meta_score'], ascending=False,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 movie_df.sort_values(by=['IMDB_Rating','Meta_score'], ascending=False,axis=1)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:6295, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6290     raise ValueError(
#    6291         f"Length of ascending ({len(ascending)}) != length of by ({len(by)})"
#    6292     )
#    6293 if len(by) > 1:
# -> 6295     keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6297     # need to rewrap columns in Series to apply key function
#    6298     if key is not None:
#    6299         # error: List comprehension has incompatible type List[Series];
#    6300         # expected List[ndarray]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:6295, in <listcomp>(.0)
#    6290     raise ValueError(
#    6291         f"Length of ascending ({len(ascending)}) != length of by ({len(by)})"
#    6292     )
#    6293 if len(by) > 1:
# -> 6295     keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6297     # need to rewrap columns in Series to apply key function
#    6298     if key is not None:
#    6299         # error: List comprehension has incompatible type List[Series];
#    6300         # expected List[ndarray]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:1840, in NDFrame._get_label_or_level_values(self, key, axis)
#    1838     values = self.axes[axis].get_level_values(key)._values
#    1839 else:
# -> 1840     raise KeyError(key)
#    1842 # Check for duplicates
#    1843 if values.ndim > 1:
#
# KeyError: 'IMDB_Rating'
